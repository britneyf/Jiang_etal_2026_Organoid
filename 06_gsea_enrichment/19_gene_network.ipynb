# %%
# Install packages
if (!require("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

BiocManager::install("PPInfer")
# Out:
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.18 (BiocManager 1.30.22), R 4.3.1 (2023-06-16)
#
# Installing package(s) 'PPInfer'
#
# also installing the dependencies ‘tidyselect’, ‘dbplyr’, ‘filelock’, ‘gsubfn’, ‘proto’, ‘chron’, ‘gtools’, ‘caTools’, ‘KernSmooth’, ‘BiocFileCache’, ‘xml2’, ‘sqldf’, ‘gplots’, ‘hash’, ‘plotrix’, ‘biomaRt’, ‘kernlab’, ‘STRINGdb’, ‘yeastExpData’
#
#
# Old packages: 'ape', 'BH', 'Biostrings', 'codetools', 'cowplot', 'cpp11',
#   'curl', 'data.table', 'DBI', 'DESeq2', 'digest', 'DOSE', 'GenomeInfoDb',
#   'ggplot2', 'ggraph', 'ggrepel', 'ggtree', 'glue', 'GOSemSim', 'graphlayouts',
#   'htmltools', 'igraph', 'lattice', 'locfit', 'MASS', 'Matrix', 'matrixStats',
#   'mgcv', 'munsell', 'pbdZMQ', 'Rcpp', 'RcppArmadillo', 'RCurl', 'repr',
# ...

# %%
# Install packages
install.packages("tidyselect", version = "1.2.1")

# %%
# Unload the tidyselect package
unloadNamespace("tidyselect")

# Load the biomaRt package
library(biomaRt)
# Out:
# Error in unloadNamespace("tidyselect"): namespace ‘tidyselect’ is imported by ‘dplyr’ so cannot be unloaded
# Traceback:
#
# 1. unloadNamespace("tidyselect")
# 2. stop(gettextf("namespace %s is imported by %s so cannot be unloaded",
#  .     sQuote(getNamespaceName(ns)), paste(sQuote(users), collapse = ", ")),
#  .     domain = NA)

# %%
# Load libraries
library('PPInfer')
# Out:
# Loading required package: biomaRt
#
# Error: package or namespace load failed for ‘biomaRt’ in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]):
#  namespace ‘tidyselect’ 1.2.0 is already loaded, but >= 1.2.1 is required
# Error: package ‘biomaRt’ could not be loaded
# Traceback:
#
# 1. library("PPInfer")
# 2. .getRequiredPackages2(pkgInfo, quietly = quietly, lib.loc = c(lib.loc,
#  .     .libPaths()))
# 3. stop(gettextf("package %s could not be loaded", sQuote(pkg)),
#  .     call. = FALSE, domain = NA)
