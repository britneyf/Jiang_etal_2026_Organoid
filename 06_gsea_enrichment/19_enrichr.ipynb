# %%
# Load libraries
suppressMessages(library('clusterProfiler'))

# %%
# Read gene list
gene_list = read.gmt('/data/chanjlab/CRC_ZFP36L2.092023/ref/pathways_for_gsea.curated.small.032624.gmt')

# %%
gene_list
# Out:
#        term                     gene
# 1      ABBUD_LIF_SIGNALING_1_UP ACAA2
# 2      ABBUD_LIF_SIGNALING_1_UP ALDOC
# 3      ABBUD_LIF_SIGNALING_1_UP ANXA8L1
# 4      ABBUD_LIF_SIGNALING_1_UP BCL3
# 5      ABBUD_LIF_SIGNALING_1_UP CEBPB
# 6      ABBUD_LIF_SIGNALING_1_UP CXCL14
# 7      ABBUD_LIF_SIGNALING_1_UP CYB561
# 8      ABBUD_LIF_SIGNALING_1_UP ELF3
# 9      ABBUD_LIF_SIGNALING_1_UP FBP1
# 10     ABBUD_LIF_SIGNALING_1_UP FGG
# 11     ABBUD_LIF_SIGNALING_1_UP GPCPD1
# 12     ABBUD_LIF_SIGNALING_1_UP GPX3
# 13     ABBUD_LIF_SIGNALING_1_UP GRAMD2B
# 14     ABBUD_LIF_SIGNALING_1_UP HAS1
# 15     ABBUD_LIF_SIGNALING_1_UP IL1R1
# 16     ABBUD_LIF_SIGNALING_1_UP IRF1
# 17     ABBUD_LIF_SIGNALING_1_UP KLF10
# 18     ABBUD_LIF_SIGNALING_1_UP KNG1
# 19     ABBUD_LIF_SIGNALING_1_UP LBP
# 20     ABBUD_LIF_SIGNALING_1_UP LCN2
# 21     ABBUD_LIF_SIGNALING_1_UP LRG1
# 22     ABBUD_LIF_SIGNALING_1_UP MAN1A1
# 23     ABBUD_LIF_SIGNALING_1_UP MPO
# 24     ABBUD_LIF_SIGNALING_1_UP NMI
# ...
